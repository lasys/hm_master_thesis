# %%
from DWave_runner import *
# %matplotlib inline

# %%
run_all(nodes=[4])
# Out:
# [('/Users/lachermeier/PycharmProjects/master_thesis_qaoa/data/04_nodes', [<networkx.classes.graph.Graph object at 0x1080cc9a0>, <networkx.classes.graph.Graph object at 0x1080cc580>, <networkx.classes.graph.Graph object at 0x1080ccd90>, <networkx.classes.graph.Graph object at 0x1080cc6d0>, <networkx.classes.graph.Graph object at 0x1080ccd60>, <networkx.classes.graph.Graph object at 0x1080cc8b0>, <networkx.classes.graph.Graph object at 0x1080cc0d0>, <networkx.classes.graph.Graph object at 0x1080cc160>, <networkx.classes.graph.Graph object at 0x12c995880>, <networkx.classes.graph.Graph object at 0x12c9958e0>]), ('/Users/lachermeier/PycharmProjects/master_thesis_qaoa/data/05_nodes', []), ('/Users/lachermeier/PycharmProjects/master_thesis_qaoa/data/06_nodes', []), ('/Users/lachermeier/PycharmProjects/master_thesis_qaoa/data/07_nodes', []), ('/Users/lachermeier/PycharmProjects/master_thesis_qaoa/data/08_nodes', []), ('/Users/lachermeier/PycharmProjects/master_thesis_qaoa/data/09_nodes', []
# ...
