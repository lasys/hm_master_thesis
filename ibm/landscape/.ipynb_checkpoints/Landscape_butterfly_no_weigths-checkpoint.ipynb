# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../'))
sys.path.insert(0, os.path.abspath('../../'))

import qiskit
provider = qiskit.IBMQ.load_account()


import numpy as np

from qiskit import Aer
from qiskit.utils import QuantumInstance
from qiskit_optimization.algorithms import MinimumEigenOptimizer
from qiskit.algorithms import QAOA
from shared.QiskitMaxcut import *
from ibm.ibm_parameters import *
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
quantum_instance = QuantumInstance(
                    backend=Aer.get_backend(DEFAULT_QASM_SIMULATOR),
                    shots=SHOTS)

# %%
# ---- Define graph and MaxCut ----
graph = load_graph()
max_cut = Maxcut(graph)
max_cut_qubo = max_cut.to_qubo()
max_cut.draw()

# %%
step_size = 0.1
a_gamma = np.arange(0, np.pi, step_size)
b_beta = np.arange(0, np.pi, step_size)

# %%
a_gamma, b_beta = np.meshgrid(a_gamma, b_beta)

# %%
def run_qaoa(gamma, beta):
    qaoa = QAOA(optimizer=SPSA(maxiter=1),
                quantum_instance=quantum_instance,
                reps=1,
                initial_point=[gamma, beta])
    algorithm = MinimumEigenOptimizer(qaoa)
    result = algorithm.solve(max_cut_qubo)
    optimal_parameters = qaoa.optimal_params
    mean, distribution = max_cut.analyse(result)

    return mean

# %%
F1 = np.zeros(a_gamma.shape)
for i in range(0, len(F1)):
    for j in range(0, len(F1)):
        # F1[i,j] = a_gamma[i][j] * b_beta[i][j]
        F1[i,j] = run_qaoa(a_gamma[i][j], b_beta[i][j])

# %%
print(F1)
plt.matshow(F1)
plt.show()
# Out:
# [[-24.073    -12.560125 -16.497375 ... -16.040125 -23.81075  -12.283375]
#  [-22.246375 -24.122    -21.427375 ... -24.78325  -21.995875 -23.475875]
#  [-23.464875 -18.18875  -25.169125 ... -24.83025  -10.41325  -21.864875]
#  ...
#  [-21.570875 -21.845375 -23.29075  ... -23.756375 -20.842375 -20.653   ]
#  [-25.2405   -27.923125 -23.454    ... -25.21775  -23.50625  -22.214625]
#  [-22.174    -20.256875 -24.15975  ... -26.67725  -20.891375 -25.011875]]

# %%
np.mean(F1)
# Out:
# -23.66644104003906

# %%
F2 = F1 - np.mean(F1)

# %%
plt.matshow(F2)
plt.show()

# %%
F2
# Out:
# array([[-0.40655896, 11.10631604,  7.16906604, ...,  7.62631604,
#         -0.14430896, 11.38306604],
#        [ 1.42006604, -0.45555896,  2.23906604, ..., -1.11680896,
#          1.67056604,  0.19056604],
#        [ 0.20156604,  5.47769104, -1.50268396, ..., -1.16380896,
#         13.25319104,  1.80156604],
#        ...,
#        [ 2.09556604,  1.82106604,  0.37569104, ..., -0.08993396,
#          2.82406604,  3.01344104],
#        [-1.57405896, -4.25668396,  0.21244104, ..., -1.55130896,
#          0.16019104,  1.45181604],
#        [ 1.49244104,  3.40956604, -0.49330896, ..., -3.01080896,
#          2.77506604, -1.34543396]])
