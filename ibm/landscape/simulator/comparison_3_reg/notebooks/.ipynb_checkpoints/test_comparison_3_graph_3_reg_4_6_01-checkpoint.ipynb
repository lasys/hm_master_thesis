# %% [markdown]
# # graph_3_reg_4_6_01

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../'))
sys.path.insert(0, os.path.abspath('../../'))
sys.path.insert(0, os.path.abspath('/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/'))
sys.path.insert(0, os.path.abspath('/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/'))
sys.path.insert(0, os.path.abspath('/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/landscape/'))
sys.path.insert(0, os.path.abspath('/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/landscape/simulator/'))
sys.path.insert(0, os.path.abspath('/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/landscape/simulator/'))

# %%
import numpy as np
import os.path

import qiskit
provider = qiskit.IBMQ.load_account()
from qiskit import Aer
from qiskit.utils import QuantumInstance
from qiskit_optimization.algorithms import MinimumEigenOptimizer
from qiskit.algorithms import QAOA
from shared.QiskitMaxcut import *
from ibm.ibm_parameters import *

from matplotlib import pyplot as plt
# %matplotlib inline

from max_cut_helper import *
# Out:
# ibmqfactory.load_account:WARNING:2021-08-30 10:56:52,652: Credentials are already in use. The existing account in the session will be replaced.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# ---- Define graph and MaxCut ----
filename = "graph_3_reg_4_6_01.txt"
graph = load_nx_graph_from(f"../data/{filename}")
opt_max_cut = -get_max_cut(graph.name)
max_cut = Maxcut(graph, opt_max_cut)
max_cut_qubo = max_cut.to_qubo()
max_cut.draw()

# %% [markdown]
# # GoemansWilliamson Solution

# %%
from qiskit_optimization.algorithms import GoemansWilliamsonOptimizer

# %%
optimizer = GoemansWilliamsonOptimizer(5)
result = optimizer.solve(max_cut_qubo)
mean, distribution = max_cut.analyse(result, print_output=True)
max_cut.plot_histogram(distribution, mean)
# Out:
# optimal function value: 4.0
# optimal value: [0 1 0 1]
# status: SUCCESS
# 0100: value: -3.000, probability: 33.3%
# 0111: value: -3.000, probability: 33.3%
# 0101: value: -4.000, probability: 33.3%
# Expectation Value: -3.333333333333333
# Highest Exp.Value: -3 with 66.667 %
# Lowest Exp.Value: -4 with 33.333 %
# Highest Probability: -3 with 66.667 %
# Ratio r: 0.33333333333333304
# Approiximation ratio: 0.8333333333333333
# MSE: 0.2777777777777779
# RMSE: 0.52704627669473

# %% [markdown]
# # Display Energy Landscape for p = 1

# %%
from landscape_helper import *

# %%
landscape_results_filename = f"landscape_simulator_{graph.name}_results.npy"

# %%
landscape = load_landscape_data(landscape_results_filename, max_cut)
# Out:
# Landscape does not exists, start calculating..
# Process SpawnProcess-574:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 50, in run_qaoa_process
#     mean = run_qaoa(gamma, beta, max_cut)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 36, in run_qaoa
#     qaoa = QAOA(optimizer=COBYLA(maxiter=0),
# NameError: name 'COBYLA' is not defined
# Process SpawnProcess-575:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 50, in run_qaoa_process
#     mean = run_qaoa(gamma, beta, max_cut)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 36, in run_qaoa
#     qaoa = QAOA(optimizer=COBYLA(maxiter=0),
# NameError: name 'COBYLA' is not defined
# Process SpawnProcess-576:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 50, in run_qaoa_process
#     mean = run_qaoa(gamma, beta, max_cut)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 36, in run_qaoa
#     qaoa = QAOA(optimizer=COBYLA(maxiter=0),
# NameError: name 'COBYLA' is not defined
# Process SpawnProcess-577:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 50, in run_qaoa_process
#     mean = run_qaoa(gamma, beta, max_cut)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 36, in run_qaoa
#     qaoa = QAOA(optimizer=COBYLA(maxiter=0),
# NameError: name 'COBYLA' is not defined
# Process SpawnProcess-578:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 50, in run_qaoa_process
#     mean = run_qaoa(gamma, beta, max_cut)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 36, in run_qaoa
#     qaoa = QAOA(optimizer=COBYLA(maxiter=0),
# NameError: name 'COBYLA' is not defined
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 6, in <module>
#     import qiskit
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/__init__.py", line 52, in <module>
#     from qiskit.execute_function import execute  # noqa
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/execute_function.py", line 24, in <module>
#     from qiskit.compiler import transpile, assemble, schedule
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/compiler/__init__.py", line 34, in <module>
#     from .transpiler import transpile
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/compiler/transpiler.py", line 34, in <module>
#     from qiskit.transpiler.passes import ApplyLayout
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/__init__.py", line 136, in <module>
#     from .layout import SetLayout
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/layout/__init__.py", line 19, in <module>
#     from .sabre_layout import SabreLayout
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/layout/sabre_layout.py", line 24, in <module>
#     from qiskit.transpiler.passes.routing import SabreSwap
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/routing/__init__.py", line 20, in <module>
#     from .bip_mapping import BIPMapping
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/routing/bip_mapping.py", line 29, in <module>
#     from qiskit.transpiler.passes.routing.algorithms.bip_model import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/routing/algorithms/bip_model.py", line 17, in <module>
#     from docplex.mp.model import Model
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/docplex/mp/model.py", line 17, in <module>
#     from docplex.mp.aggregator import ModelAggregator
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/docplex/mp/aggregator.py", line 14, in <module>
#     from docplex.mp.utils import is_number, is_iterable, is_iterator, is_pandas_series, \
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/docplex/mp/utils.py", line 79, in <module>
#     from pandas import Series, DataFrame
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pandas/__init__.py", line 179, in <module>
#     import pandas.testing
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pandas/testing.py", line 6, in <module>
#     from pandas._testing import (
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 657, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 562, in module_from_spec
#   File "<frozen importlib._bootstrap>", line 517, in _init_module_attrs
#   File "<frozen importlib._bootstrap>", line 389, in parent
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 6, in <module>
#     import qiskit
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/__init__.py", line 26, in <module>
#     from qiskit.circuit import ClassicalRegister
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/circuit/__init__.py", line 231, in <module>
#     from .classicalfunction.types import Int1, Int2
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/circuit/classicalfunction/__init__.py", line 98, in <module>
#     from .classicalfunction import ClassicalFunction
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/circuit/classicalfunction/classicalfunction.py", line 25, in <module>
#     from .utils import tweedledum2qiskit
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/circuit/classicalfunction/utils.py", line 20, in <module>
#     from qiskit.circuit.library.standard_gates import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/circuit/library/__init__.py", line 395, in <module>
#     from .quantum_volume import QuantumVolume
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/circuit/library/quantum_volume.py", line 18, in <module>
#     from qiskit.quantum_info.random import random_unitary
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/quantum_info/__init__.py", line 124, in <module>
#     from .operators import Operator, ScalarOp, Pauli, Clifford, SparsePauliOp
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/quantum_info/operators/__init__.py", line 18, in <module>
#     from .measures import process_fidelity, average_gate_fidelity, gate_error, diamond_norm
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/quantum_info/operators/measures.py", line 32, in <module>
#     import cvxpy
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cvxpy/__init__.py", line 23, in <module>
#     from cvxpy.problems.problem import Problem
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cvxpy/problems/problem.py", line 30, in <module>
#     from cvxpy.reductions import InverseData
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cvxpy/reductions/__init__.py", line 32, in <module>
#     from cvxpy.reductions.solvers.solving_chain import SolvingChain
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cvxpy/reductions/solvers/solving_chain.py", line 22, in <module>
#     from cvxpy.reductions.solvers import defines as slv_def
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cvxpy/reductions/solvers/defines.py", line 105, in <module>
#     INSTALLED_SOLVERS = installed_solvers()
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cvxpy/reductions/solvers/defines.py", line 94, in installed_solvers
#     if solver.is_installed():
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cvxpy/reductions/solvers/solver.py", line 58, in is_installed
#     self.import_solver()
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cvxpy/reductions/solvers/conic_solvers/scipy_conif.py", line 48, in import_solver
#     from scipy import optimize as opt
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/optimize/__init__.py", line 421, in <module>
#     from ._shgo import shgo
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/optimize/_shgo.py", line 9, in <module>
#     from scipy import spatial
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/spatial/__init__.py", line 107, in <module>
#     from . import distance, transform
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/spatial/transform/__init__.py", line 19, in <module>
#     from .rotation import Rotation, Slerp
#   File "rotation.pyx", line 5, in init scipy.spatial.transform.rotation
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/spatial/transform/_rotation_groups.py", line 2, in <module>
#     from scipy.constants import golden as phi
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/constants/__init__.py", line 328, in <module>
#     for _x in sorted(_constant_names)])
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/shared/QiskitMaxcut.py", line 20, in <module>
#     from matplotlib import pyplot as plt
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/pyplot.py", line 44, in <module>
#     from matplotlib.figure import Figure, figaspect
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/figure.py", line 24, in <module>
#     from matplotlib import docstring, projections
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/projections/__init__.py", line 1, in <module>
#     from .. import axes, docstring
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/axes/__init__.py", line 1, in <module>
#     from ._subplots import *
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/axes/_subplots.py", line 203, in <module>
#     docstring.interpd.update(Axes_kwdoc=martist.kwdoc(Axes))
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/artist.py", line 1711, in kwdoc
#     'Properties:\n' + '\n'.join(ai.pprint_setters(leadingspace=4)))
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/artist.py", line 1471, in pprint_setters
#     accepts = self.get_valid_values(prop)
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/artist.py", line 1379, in get_valid_values
#     return re.sub("\n *", " ", match.group(1))
#   File "/usr/lib64/python3.8/re.py", line 210, in sub
#     return _compile(pattern, flags).sub(repl, string, count)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 12, in <module>
#     from qiskit_optimization.algorithms import MinimumEigenOptimizer
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit_optimization/algorithms/__init__.py", line 66, in <module>
#     from .admm_optimizer import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit_optimization/algorithms/admm_optimizer.py", line 20, in <module>
#     from qiskit.algorithms import NumPyMinimumEigensolver
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/algorithms/__init__.py", line 168, in <module>
#     from .amplitude_estimators import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/algorithms/amplitude_estimators/__init__.py", line 16, in <module>
#     from .ae import AmplitudeEstimation, AmplitudeEstimationResult
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/algorithms/amplitude_estimators/ae.py", line 18, in <module>
#     from scipy.stats import chi2, norm
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/stats/__init__.py", line 441, in <module>
#     from .stats import *
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/stats/stats.py", line 43, in <module>
#     from . import distributions
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/stats/distributions.py", line 10, in <module>
#     from . import _continuous_distns
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py", line 181, in <module>
#     kstwo = kstwo_gen(momtype=0, a=0.0, b=1.0, name='kstwo')
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py", line 1739, in __init__
#     self._construct_doc(docdict, dct.get(self.name))
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py", line 824, in _construct_doc
#     self.__doc__ = doccer.docformat(self.__doc__, tempdict)
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/_lib/doccer.py", line 62, in docformat
#     newlines.append(indent+line)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 6, in <module>
#     import qiskit
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/__init__.py", line 52, in <module>
#     from qiskit.execute_function import execute  # noqa
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/execute_function.py", line 24, in <module>
#     from qiskit.compiler import transpile, assemble, schedule
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/compiler/__init__.py", line 34, in <module>
#     from .transpiler import transpile
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/compiler/transpiler.py", line 34, in <module>
#     from qiskit.transpiler.passes import ApplyLayout
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/__init__.py", line 136, in <module>
#     from .layout import SetLayout
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/layout/__init__.py", line 19, in <module>
#     from .sabre_layout import SabreLayout
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/layout/sabre_layout.py", line 24, in <module>
#     from qiskit.transpiler.passes.routing import SabreSwap
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/routing/__init__.py", line 20, in <module>
#     from .bip_mapping import BIPMapping
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/routing/bip_mapping.py", line 29, in <module>
#     from qiskit.transpiler.passes.routing.algorithms.bip_model import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/routing/algorithms/bip_model.py", line 17, in <module>
#     from docplex.mp.model import Model
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/docplex/mp/model.py", line 23, in <module>
#     from docplex.mp.context import Context, OverridenOutputContext
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/docplex/mp/context.py", line 46, in <module>
#     from docplex.util.environment import get_environment
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/docplex/util/environment.py", line 741, in <module>
#     from .ws.util import START_SOLVE_EVENT, END_SOLVE_EVENT, Tracker
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/docplex/util/ws/util.py", line 12, in <module>
#     from IPython.display import Javascript, HTML, display
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/IPython/__init__.py", line 56, in <module>
#     from .terminal.embed import embed
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/IPython/terminal/embed.py", line 17, in <module>
#     from IPython.terminal.ipapp import load_default_config
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/IPython/terminal/ipapp.py", line 28, in <module>
#     from IPython.core.magics import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/IPython/core/magics/__init__.py", line 25, in <module>
#     from .namespace import NamespaceMagics
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/IPython/core/magics/namespace.py", line 34, in <module>
#     class NamespaceMagics(Magics):
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/IPython/core/magics/namespace.py", line 479, in NamespaceMagics
#     def reset(self, parameter_s=''):
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/IPython/core/magic.py", line 193, in magic_deco
#     retval = decorator(call, func)
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/decorator.py", line 262, in decorator
#     return decorate(_func, caller)
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/decorator.py", line 250, in decorate
#     fun = FunctionMaker.create(
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/decorator.py", line 213, in create
#     self = cls(func, name, signature, defaults, doc, module)
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/decorator.py", line 126, in __init__
#     self.dict = func.__dict__.copy()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 6, in <module>
#     import qiskit
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/__init__.py", line 46, in <module>
#     from qiskit.providers.basicaer import BasicAer
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/basicaer/__init__.py", line 65, in <module>
#     from .basicaerprovider import BasicAerProvider
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/basicaer/basicaerprovider.py", line 24, in <module>
#     from .qasm_simulator import QasmSimulatorPy
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/basicaer/qasm_simulator.py", line 48, in <module>
#     from .basicaertools import single_gate_matrix
#   File "<frozen importlib._bootstrap>", line 988, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 149, in __enter__
#   File "<frozen importlib._bootstrap>", line 92, in acquire
# KeyboardInterrupt
# Process SpawnProcess-580:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 50, in run_qaoa_process
#     mean = run_qaoa(gamma, beta, max_cut)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 32, in run_qaoa
#     quantum_instance = QuantumInstance(
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/utils/quantum_instance.py", line 294, in __init__
#     if is_ibmq_provider(self._backend):
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/utils/backend_utils.py", line 111, in is_ibmq_provider
#     if has_ibmq():
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/utils/backend_utils.py", line 41, in has_ibmq
#     from qiskit.providers.ibmq import IBMQFactory
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/__init__.py", line 88, in <module>
#     from .ibmqfactory import IBMQFactory
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/ibmqfactory.py", line 20, in <module>
#     from .accountprovider import AccountProvider
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/accountprovider.py", line 28, in <module>
#     from qiskit.providers.ibmq.runtime import runtime_job  # pylint: disable=unused-import
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/runtime/__init__.py", line 228, in <module>
#     from .ibm_runtime_service import IBMRuntimeService
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/runtime/ibm_runtime_service.py", line 23, in <module>
#     from .runtime_job import RuntimeJob
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/runtime/runtime_job.py", line 30, in <module>
#     from ..api.clients import RuntimeClient, RuntimeWebsocketClient, WebsocketClientCloseCode
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/api/clients/__init__.py", line 15, in <module>
#     from .base import BaseClient, WebsocketClientCloseCode
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/api/clients/base.py", line 27, in <module>
#     from ...credentials import Credentials
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/credentials/__init__.py", line 44, in <module>
#     from .credentials import Credentials
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/credentials/credentials.py", line 18, in <module>
#     from requests_ntlm import HttpNtlmAuth
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/requests_ntlm/__init__.py", line 1, in <module>
#     from .requests_ntlm import HttpNtlmAuth
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/requests_ntlm/requests_ntlm.py", line 10, in <module>
#     from requests.auth import AuthBase
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/requests/__init__.py", line 53, in <module>
#     from chardet import __version__ as chardet_version
#   File "/usr/lib/python3.6/site-packages/chardet/__init__.py", line 20, in <module>
#     from .universaldetector import UniversalDetector
#   File "/usr/lib/python3.6/site-packages/chardet/universaldetector.py", line 45, in <module>
#     from .escprober import EscCharSetProber
#   File "/usr/lib/python3.6/site-packages/chardet/escprober.py", line 31, in <module>
#     from .escsm import (HZ_SM_MODEL, ISO2022CN_SM_MODEL, ISO2022JP_SM_MODEL,
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/shared/QiskitMaxcut.py", line 17, in <module>
#     import networkx as nx
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/networkx/__init__.py", line 47, in <module>
#     import networkx.classes.filters
#   File "<frozen importlib._bootstrap>", line 988, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 148, in __enter__
#   File "<frozen importlib._bootstrap>", line 187, in _get_module_lock
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 6, in <module>
#     import qiskit
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/__init__.py", line 46, in <module>
#     from qiskit.providers.basicaer import BasicAer
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/__init__.py", line 551, in <module>
#     from qiskit.providers.basebackend import BaseBackend
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/basebackend.py", line 22, in <module>
#     from qiskit.version import VERSION as __version__
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/version.py", line 20, in <module>
#     import pkg_resources
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pkg_resources/__init__.py", line 538, in <module>
#     class WorkingSet:
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pkg_resources/__init__.py", line 538, in WorkingSet
#     class WorkingSet:
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 12, in <module>
#     from qiskit_optimization.algorithms import MinimumEigenOptimizer
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit_optimization/algorithms/__init__.py", line 66, in <module>
#     from .admm_optimizer import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit_optimization/algorithms/admm_optimizer.py", line 20, in <module>
#     from qiskit.algorithms import NumPyMinimumEigensolver
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/algorithms/__init__.py", line 168, in <module>
#     from .amplitude_estimators import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/algorithms/amplitude_estimators/__init__.py", line 16, in <module>
#     from .ae import AmplitudeEstimation, AmplitudeEstimationResult
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/algorithms/amplitude_estimators/ae.py", line 18, in <module>
#     from scipy.stats import chi2, norm
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/stats/__init__.py", line 441, in <module>
#     from .stats import *
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/stats/stats.py", line 43, in <module>
#     from . import distributions
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/stats/distributions.py", line 10, in <module>
#     from . import _continuous_distns
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/stats/_continuous_distns.py", line 7586, in <module>
#     trapezoid = trapezoid_gen(a=0.0, b=1.0, name="trapezoid")
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py", line 1739, in __init__
#     self._construct_doc(docdict, dct.get(self.name))
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py", line 824, in _construct_doc
#     self.__doc__ = doccer.docformat(self.__doc__, tempdict)
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/_lib/doccer.py", line 62, in docformat
#     newlines.append(indent+line)
# KeyboardInterrupt
# Process SpawnProcess-581:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 50, in run_qaoa_process
#     mean = run_qaoa(gamma, beta, max_cut)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 32, in run_qaoa
#     quantum_instance = QuantumInstance(
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/utils/quantum_instance.py", line 294, in __init__
#     if is_ibmq_provider(self._backend):
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/utils/backend_utils.py", line 111, in is_ibmq_provider
#     if has_ibmq():
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/utils/backend_utils.py", line 41, in has_ibmq
#     from qiskit.providers.ibmq import IBMQFactory
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/__init__.py", line 88, in <module>
#     from .ibmqfactory import IBMQFactory
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/ibmqfactory.py", line 20, in <module>
#     from .accountprovider import AccountProvider
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/accountprovider.py", line 28, in <module>
#     from qiskit.providers.ibmq.runtime import runtime_job  # pylint: disable=unused-import
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/runtime/__init__.py", line 228, in <module>
#     from .ibm_runtime_service import IBMRuntimeService
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/runtime/ibm_runtime_service.py", line 23, in <module>
#     from .runtime_job import RuntimeJob
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/runtime/runtime_job.py", line 30, in <module>
#     from ..api.clients import RuntimeClient, RuntimeWebsocketClient, WebsocketClientCloseCode
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/api/clients/__init__.py", line 15, in <module>
#     from .base import BaseClient, WebsocketClientCloseCode
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/api/clients/base.py", line 27, in <module>
#     from ...credentials import Credentials
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/credentials/__init__.py", line 44, in <module>
#     from .credentials import Credentials
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/ibmq/credentials/credentials.py", line 18, in <module>
#     from requests_ntlm import HttpNtlmAuth
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/requests_ntlm/__init__.py", line 1, in <module>
#     from .requests_ntlm import HttpNtlmAuth
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/requests_ntlm/requests_ntlm.py", line 5, in <module>
#     from cryptography import x509
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cryptography/x509/__init__.py", line 7, in <module>
#     from cryptography.x509.base import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cryptography/x509/base.py", line 12, in <module>
#     from cryptography.hazmat._types import _PRIVATE_KEY_TYPES, _PUBLIC_KEY_TYPES
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cryptography/hazmat/_types.py", line 7, in <module>
#     from cryptography.hazmat.primitives.asymmetric import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cryptography/hazmat/primitives/asymmetric/ec.py", line 21, in <module>
#     class EllipticCurveOID(object):
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cryptography/hazmat/primitives/asymmetric/ec.py", line 23, in EllipticCurveOID
#     SECP224R1 = ObjectIdentifier("1.3.132.0.33")
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cryptography/hazmat/_oid.py", line 21, in __init__
#     node_value = int(node, 10)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 6, in <module>
#     import qiskit
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/__init__.py", line 52, in <module>
#     from qiskit.execute_function import execute  # noqa
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/execute_function.py", line 24, in <module>
#     from qiskit.compiler import transpile, assemble, schedule
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/compiler/__init__.py", line 34, in <module>
#     from .transpiler import transpile
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/compiler/transpiler.py", line 34, in <module>
#     from qiskit.transpiler.passes import ApplyLayout
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/__init__.py", line 136, in <module>
#     from .layout import SetLayout
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/layout/__init__.py", line 19, in <module>
#     from .sabre_layout import SabreLayout
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/layout/sabre_layout.py", line 24, in <module>
#     from qiskit.transpiler.passes.routing import SabreSwap
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/routing/__init__.py", line 20, in <module>
#     from .bip_mapping import BIPMapping
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/routing/bip_mapping.py", line 29, in <module>
#     from qiskit.transpiler.passes.routing.algorithms.bip_model import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/routing/algorithms/bip_model.py", line 17, in <module>
#     from docplex.mp.model import Model
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/docplex/mp/model.py", line 23, in <module>
#     from docplex.mp.context import Context, OverridenOutputContext
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/docplex/mp/context.py", line 46, in <module>
#     from docplex.util.environment import get_environment
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/docplex/util/environment.py", line 741, in <module>
#     from .ws.util import START_SOLVE_EVENT, END_SOLVE_EVENT, Tracker
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/docplex/util/ws/util.py", line 12, in <module>
#     from IPython.display import Javascript, HTML, display
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/IPython/__init__.py", line 56, in <module>
#     from .terminal.embed import embed
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/IPython/terminal/embed.py", line 16, in <module>
#     from IPython.terminal.interactiveshell import TerminalInteractiveShell
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/IPython/terminal/interactiveshell.py", line 35, in <module>
#     from .debugger import TerminalPdb, Pdb
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/IPython/terminal/debugger.py", line 8, in <module>
#     from IPython.core.completer import IPCompleter
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/IPython/core/completer.py", line 146, in <module>
#     import jedi
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/jedi/__init__.py", line 32, in <module>
#     from jedi.api import Script, Interpreter, set_debug_function, preload_module
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/jedi/api/__init__.py", line 13, in <module>
#     import parso
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 914, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1342, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1317, in _get_spec
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 6, in <module>
#     import qiskit
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/__init__.py", line 52, in <module>
#     from qiskit.execute_function import execute  # noqa
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/execute_function.py", line 24, in <module>
#     from qiskit.compiler import transpile, assemble, schedule
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/compiler/__init__.py", line 34, in <module>
#     from .transpiler import transpile
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/compiler/transpiler.py", line 34, in <module>
#     from qiskit.transpiler.passes import ApplyLayout
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/__init__.py", line 136, in <module>
#     from .layout import SetLayout
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/layout/__init__.py", line 19, in <module>
#     from .sabre_layout import SabreLayout
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/layout/sabre_layout.py", line 24, in <module>
#     from qiskit.transpiler.passes.routing import SabreSwap
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/routing/__init__.py", line 20, in <module>
#     from .bip_mapping import BIPMapping
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/routing/bip_mapping.py", line 29, in <module>
#     from qiskit.transpiler.passes.routing.algorithms.bip_model import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/routing/algorithms/bip_model.py", line 17, in <module>
#     from docplex.mp.model import Model
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/docplex/mp/model.py", line 23, in <module>
#     from docplex.mp.context import Context, OverridenOutputContext
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/docplex/mp/context.py", line 46, in <module>
#     from docplex.util.environment import get_environment
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/docplex/util/environment.py", line 741, in <module>
#     from .ws.util import START_SOLVE_EVENT, END_SOLVE_EVENT, Tracker
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/docplex/util/ws/util.py", line 12, in <module>
#     from IPython.display import Javascript, HTML, display
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/IPython/__init__.py", line 56, in <module>
#     from .terminal.embed import embed
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/IPython/terminal/embed.py", line 15, in <module>
#     from IPython.core.interactiveshell import DummyMod, InteractiveShell
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 339, in <module>
#     class InteractiveShell(SingletonConfigurable):
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 603, in InteractiveShell
#     payload_manager = Instance('IPython.core.payload.PayloadManager', allow_none=True)
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/traitlets/traitlets.py", line 1795, in __init__
#     def __init__(self, klass=None, args=None, kw=None, **kwargs):
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 6, in <module>
#     import qiskit
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/__init__.py", line 52, in <module>
#     from qiskit.execute_function import execute  # noqa
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/execute_function.py", line 24, in <module>
#     from qiskit.compiler import transpile, assemble, schedule
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/compiler/__init__.py", line 34, in <module>
#     from .transpiler import transpile
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/compiler/transpiler.py", line 34, in <module>
#     from qiskit.transpiler.passes import ApplyLayout
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/__init__.py", line 136, in <module>
#     from .layout import SetLayout
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/layout/__init__.py", line 19, in <module>
#     from .sabre_layout import SabreLayout
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/layout/sabre_layout.py", line 24, in <module>
#     from qiskit.transpiler.passes.routing import SabreSwap
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/routing/__init__.py", line 20, in <module>
#     from .bip_mapping import BIPMapping
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/routing/bip_mapping.py", line 29, in <module>
#     from qiskit.transpiler.passes.routing.algorithms.bip_model import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/transpiler/passes/routing/algorithms/bip_model.py", line 17, in <module>
#     from docplex.mp.model import Model
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/docplex/mp/model.py", line 17, in <module>
#     from docplex.mp.aggregator import ModelAggregator
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/docplex/mp/aggregator.py", line 14, in <module>
#     from docplex.mp.utils import is_number, is_iterable, is_iterator, is_pandas_series, \
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/docplex/mp/utils.py", line 79, in <module>
#     from pandas import Series, DataFrame
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pandas/__init__.py", line 50, in <module>
#     from pandas.core.api import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pandas/core/api.py", line 48, in <module>
#     from pandas.core.groupby import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pandas/core/groupby/__init__.py", line 1, in <module>
#     from pandas.core.groupby.generic import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pandas/core/groupby/generic.py", line 73, in <module>
#     from pandas.core.frame import DataFrame
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pandas/core/frame.py", line 129, in <module>
#     from pandas.core import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pandas/core/generic.py", line 141, in <module>
#     from pandas.core.window import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pandas/core/window/__init__.py", line 5, in <module>
#     from pandas.core.window.expanding import (  # noqa:F401
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pandas/core/window/expanding.py", line 40, in <module>
#     class Expanding(RollingAndExpandingMixin):
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pandas/core/window/expanding.py", line 377, in Expanding
#     @doc(
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pandas/util/_decorators.py", line 348, in doc
#     def doc(*docstrings: str | Callable, **params) -> Callable[[F], F]:
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/shared/QiskitMaxcut.py", line 17, in <module>
#     import networkx as nx
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/networkx/__init__.py", line 61, in <module>
#     import networkx.generators
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/networkx/generators/__init__.py", line 16, in <module>
#     from networkx.generators.intersection import *
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/networkx/generators/intersection.py", line 5, in <module>
#     from networkx.algorithms import bipartite
# ...
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/shared/QiskitMaxcut.py", line 20, in <module>
#     from matplotlib import pyplot as plt
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/pyplot.py", line 44, in <module>
#     from matplotlib.figure import Figure, figaspect
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/figure.py", line 24, in <module>
#     from matplotlib import docstring, projections
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/projections/__init__.py", line 1, in <module>
#     from .. import axes, docstring
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/axes/__init__.py", line 1, in <module>
#     from ._subplots import *
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/axes/_subplots.py", line 5, in <module>
#     from matplotlib.axes._axes import Axes
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py", line 34, in <module>
#     from matplotlib.axes._base import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 23, in <module>
#     import matplotlib.axis as maxis
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/axis.py", line 28, in <module>
#     _line_inspector = martist.ArtistInspector(mlines.Line2D)
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/artist.py", line 1326, in __init__
#     self.aliasd = self.get_aliases()
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/artist.py", line 1345, in get_aliases
#     if not self.is_alias(func):
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/artist.py", line 1424, in is_alias
#     ds = inspect.getdoc(o)
#   File "/usr/lib64/python3.8/inspect.py", line 623, in getdoc
#     return cleandoc(doc)
#   File "/usr/lib64/python3.8/inspect.py", line 641, in cleandoc
#     margin = min(margin, indent)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/shared/QiskitMaxcut.py", line 20, in <module>
#     from matplotlib import pyplot as plt
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/__init__.py", line 107, in <module>
#     from . import _api, cbook, docstring, rcsetup
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/rcsetup.py", line 24, in <module>
#     from matplotlib import _api, animation, cbook
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/animation.py", line 37, in <module>
#     from matplotlib._animation_data import (
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 779, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 863, in get_code
#   File "<frozen importlib._bootstrap_external>", line 336, in cache_from_source
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 6, in <module>
#     import qiskit
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/__init__.py", line 46, in <module>
#     from qiskit.providers.basicaer import BasicAer
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/__init__.py", line 551, in <module>
#     from qiskit.providers.basebackend import BaseBackend
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/providers/basebackend.py", line 22, in <module>
#     from qiskit.version import VERSION as __version__
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/version.py", line 20, in <module>
#     import pkg_resources
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pkg_resources/__init__.py", line 3243, in <module>
#     def _initialize_master_working_set():
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pkg_resources/__init__.py", line 3226, in _call_aside
#     f(*args, **kwargs)
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pkg_resources/__init__.py", line 3278, in _initialize_master_working_set
#     list(map(working_set.add_entry, sys.path))
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pkg_resources/__init__.py", line 608, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2059, in find_on_path
#     path_item_entries = _by_version_descending(filtered)
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2029, in _by_version_descending
#     return sorted(names, key=_by_version, reverse=True)
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2027, in _by_version
#     return [packaging.version.parse(part) for part in parts]
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pkg_resources/__init__.py", line 2027, in <listcomp>
#     return [packaging.version.parse(part) for part in parts]
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pkg_resources/_vendor/packaging/version.py", line 56, in parse
#     return Version(version)
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pkg_resources/_vendor/packaging/version.py", line 275, in __init__
#     match = self._regex.search(version)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/shared/QiskitMaxcut.py", line 20, in <module>
#     from matplotlib import pyplot as plt
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/__init__.py", line 107, in <module>
#     from . import _api, cbook, docstring, rcsetup
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/rcsetup.py", line 27, in <module>
#     from matplotlib.fontconfig_pattern import parse_fontconfig_pattern
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/fontconfig_pattern.py", line 174, in <module>
#     parse_fontconfig_pattern = lru_cache()(FontconfigPatternParser().parse)
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/matplotlib/fontconfig_pattern.py", line 88, in __init__
#     size
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pyparsing.py", line 2174, in __add__
#     return And([self, other])
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pyparsing.py", line 4025, in __init__
#     super(And, self).__init__(exprs, savelist)
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/pyparsing.py", line 3880, in __init__
#     exprs = list(exprs)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/usr/lib64/python3.8/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/home/hm-tlacherm/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py", line 6, in <module>
#     import qiskit
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/__init__.py", line 26, in <module>
#     from qiskit.circuit import ClassicalRegister
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/circuit/__init__.py", line 231, in <module>
#     from .classicalfunction.types import Int1, Int2
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/circuit/classicalfunction/__init__.py", line 98, in <module>
#     from .classicalfunction import ClassicalFunction
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/circuit/classicalfunction/classicalfunction.py", line 25, in <module>
#     from .utils import tweedledum2qiskit
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/circuit/classicalfunction/utils.py", line 20, in <module>
#     from qiskit.circuit.library.standard_gates import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/circuit/library/__init__.py", line 395, in <module>
#     from .quantum_volume import QuantumVolume
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/circuit/library/quantum_volume.py", line 18, in <module>
#     from qiskit.quantum_info.random import random_unitary
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/quantum_info/__init__.py", line 124, in <module>
#     from .operators import Operator, ScalarOp, Pauli, Clifford, SparsePauliOp
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/quantum_info/operators/__init__.py", line 18, in <module>
#     from .measures import process_fidelity, average_gate_fidelity, gate_error, diamond_norm
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/qiskit/quantum_info/operators/measures.py", line 32, in <module>
#     import cvxpy
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cvxpy/__init__.py", line 23, in <module>
#     from cvxpy.problems.problem import Problem
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cvxpy/problems/problem.py", line 30, in <module>
#     from cvxpy.reductions import InverseData
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cvxpy/reductions/__init__.py", line 32, in <module>
#     from cvxpy.reductions.solvers.solving_chain import SolvingChain
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cvxpy/reductions/solvers/solving_chain.py", line 22, in <module>
#     from cvxpy.reductions.solvers import defines as slv_def
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cvxpy/reductions/solvers/defines.py", line 105, in <module>
#     INSTALLED_SOLVERS = installed_solvers()
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cvxpy/reductions/solvers/defines.py", line 94, in installed_solvers
#     if solver.is_installed():
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cvxpy/reductions/solvers/solver.py", line 58, in is_installed
#     self.import_solver()
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/cvxpy/reductions/solvers/conic_solvers/scipy_conif.py", line 48, in import_solver
#     from scipy import optimize as opt
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/optimize/__init__.py", line 401, in <module>
#     from ._minimize import *
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/optimize/_minimize.py", line 27, in <module>
#     from ._trustregion_constr import _minimize_trustregion_constr
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/optimize/_trustregion_constr/__init__.py", line 4, in <module>
#     from .minimize_trustregion_constr import _minimize_trustregion_constr
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/optimize/_trustregion_constr/minimize_trustregion_constr.py", line 5, in <module>
#     from .._constraints import (
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/scipy/optimize/_constraints.py", line 8, in <module>
#     from numpy.testing import suppress_warnings
#   File "/home/hm-tlacherm/.local/lib/python3.8/site-packages/numpy/testing/__init__.py", line 8, in <module>
#     from unittest import TestCase
#   File "/usr/lib64/python3.8/unittest/__init__.py", line 60, in <module>
#     from .async_case import IsolatedAsyncioTestCase
#   File "/usr/lib64/python3.8/unittest/async_case.py", line 1, in <module>
#     import asyncio
#   File "/usr/lib64/python3.8/asyncio/__init__.py", line 8, in <module>
#     from .base_events import *
#   File "/usr/lib64/python3.8/asyncio/base_events.py", line 40, in <module>
#     from . import events
#   File "<frozen importlib._bootstrap>", line 991, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 975, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 671, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 779, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 911, in get_code
#   File "<frozen importlib._bootstrap_external>", line 580, in _compile_bytecode
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2069804/54046862.py in <module>
# ----> 1 landscape = load_landscape_data(landscape_results_filename, max_cut)
#
# ~/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/landscape/simulator/landscape_helper.py in load_landscape_data(filename, max_cut)
#      19     if os.path.isfile(filename) == False:
#      20         print("Landscape does not exists, start calculating..")
# ---> 21         calculate_landscape_data(filename, max_cut)
#      22
#      23     f = open(filename, 'rb')
#
# ~/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/landscape/simulator/landscape_helper.py in calculate_landscape_data(filename, max_cut)
#      10
#      11 def calculate_landscape_data(filename, max_cut):
# ---> 12     landscape = run_all(l_gammas, l_betas, max_cut)
#      13     # Save result matrix
#      14     with open(filename, 'wb') as f:
#
# ~/qlm_notebooks/notebooks_1.2.1/notebooks/master_thesis_qaoa/ibm/ibm_landscape_processes.py in run_all(a_gamma, b_beta, max_cut)
#      66
#      67         for pp in processes:
# ---> 68             pp.join()
#      69
#      70         for j in range(0,len(arr)):
#
# /usr/lib64/python3.8/multiprocessing/process.py in join(self, timeout)
#     147         assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148         assert self._popen is not None, 'can only join a started process'
# --> 149         res = self._popen.wait(timeout)
#     150         if res is not None:
#     151             _children.discard(self)
#
# /usr/lib64/python3.8/multiprocessing/popen_fork.py in wait(self, timeout)
#      45                     return None
#      46             # This shouldn't block if wait() returned successfully.
# ---> 47             return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      48         return self.returncode
#      49
#
# /usr/lib64/python3.8/multiprocessing/popen_fork.py in poll(self, flag)
#      25         if self.returncode is None:
#      26             try:
# ---> 27                 pid, sts = os.waitpid(self.pid, flag)
#      28             except OSError as e:
#      29                 # Child process not yet created. See #1731717
#
# KeyboardInterrupt:

# %%
min_gamma, min_beta, min_exp = describe_landscape(landscape)

# %%
from plot_helper import *

# %%
# Plot landscape in 3D 
plot_landscape_3d(landscape)

# %%
# Plot Heatmap 
heatmap = plot_heatmap(landscape)
heatmap = display_minimum(heatmap, min_gamma, min_beta, min_exp)

# %% [markdown]
# #### Find initial points with TQA

# %%
from tqa import calculate_tqa

# %%
p = 1

# %%
tqa_initial_points = calculate_tqa(graph, p)

# %% [markdown]
# #### Run QAOA with init_points, different optimizers and plot results

# %%
from qaoa_helper import *

# %%
qnSpsa = QNSPSA(calculate_fidelity(create_qaoa(), max_cut_qubo), maxiter=50)
optimizers = [
    ('COBYLA',COBYLA(maxiter=50)),
    ('SPSA', SPSA(maxiter=50)),
    ('QNSPSA', qnSpsa),
]

# %%
for optimizer_tuple in optimizers:
    optimizer_name, optimizer = optimizer_tuple
    # create qaoa 
    qaoa = create_qaoa(optimizer = optimizer,
            reps=p,
            initial_point=tqa_initial_points,
            with_callback=True
           )
    # run qaoa 
    result, optimal_parameters, optimizer_history = run_qaoa_with_callback(qaoa, max_cut_qubo)
    
    # analyse results 
    print(f"{optimizer_name} Optimizer")
    mean, distribution = max_cut.analyse(result, print_output=True)
    max_cut.plot_histogram(distribution, mean)
    optimizer_history[2][-1] = mean
    print()
    
    # Display Optimizer Results
    counts, energy_values, maxcut_values, optimizer_gammas, optimizer_betas = optimizer_history
    display_optimizer_path(heatmap, optimizer_gammas, optimizer_betas, maxcut_values, optimizer_name)
    
    # Plot Optimizer History MaxCut Evaluation # Values from landscape -> real values may deviate 
    plot_optimizer_maxcut_history(counts, maxcut_values, optimizer_name)
    
    # Plot Optimizer History Energy Evaluation -> not MaxCutMean! 
    plot_optimizer_energy_history(counts, energy_values, optimizer_name)

# %% [markdown]
# # Comparison

# %% [markdown]
# ## Parameters

# %%
eval_num = 50
max_p = 10
all_results = {}

# %% [markdown]
# ## QAOA

# %%
from qaoa_helper import *

# %%
qaoa_p_means = []
qaoa_p_ratios = []
qaoa_p_approx_ratios = []

for p in range(1,max_p+1):
    m, r, ar = start_qaoa_evaluation(max_cut, eval_num=eval_num, reps=p)
    qaoa_p_means.append(m)
    qaoa_p_ratios.append(r)
    qaoa_p_approx_ratios.append(ar)

all_results["QAOA"] = [qaoa_p_means, qaoa_p_ratios, qaoa_p_approx_ratios]

# %%
display_boxplots_results(qaoa_p_means, qaoa_p_ratios, qaoa_p_approx_ratios)

# %% [markdown]
# ## QAOA with TQA

# %%
from qaoa_helper import *

# %%
tqa_p_means = []
tqa_p_ratios = []
tqa_p_approx_ratios = []
tqa_init_points = []

for p in range(1,max_p+1):
    tqa_initial_points = calculate_tqa(graph, p)
    m, r, ar = start_qaoa_evaluation(max_cut, eval_num=eval_num, reps=p, init_points=tqa_initial_points)
    tqa_p_means.append(m)
    tqa_p_ratios.append(r)
    tqa_p_approx_ratios.append(ar)
    tqa_init_points.append(tqa_initial_points)
    
all_results["TQA QAOA"] = [tqa_p_means, tqa_p_ratios, tqa_p_approx_ratios, tqa_init_points]

# %%
display_boxplots_results(tqa_p_means, tqa_p_ratios, tqa_p_approx_ratios, prefix='TQA ')

# %% [markdown]
# ## WarmStart QAOA

# %%
from warmstart_helper import *

# %%
ws_p_means = []
ws_p_ratios = []
ws_p_approx_ratios = []
ws_opt_epsilons = []

for p in range(1,max_p+1):
    opt_epsilon = 0.25 #optimize_epsilon(max_cut, reps=p)
    m, r, ar = start_ws_qaoa_evaluation(max_cut, eval_num=eval_num, reps=p, epsilon=opt_epsilon)
    ws_p_means.append(m)
    ws_p_ratios.append(r)
    ws_p_approx_ratios.append(ar)
    ws_opt_epsilons.append(opt_epsilon)
    
all_results["WarmStart QAOA"] = [ws_p_means, ws_p_ratios, ws_p_approx_ratios, ws_opt_epsilons]

# %%
display_boxplots_results(ws_p_means, ws_p_ratios, ws_p_approx_ratios, prefix='WarmStart ')

# %% [markdown]
# ### Recursive QAOA

# %%
from recursive_qaoa_helper import *

# %%
recursive_p_means = []
recursive_p_ratios = []
recursive_p_approx_ratios = []

for p in range(1,max_p+1):
    m, r, ar = start_recursive_evaluation(max_cut, eval_num=eval_num, reps=p)
    recursive_p_means.append(m)
    recursive_p_ratios.append(r)
    recursive_p_approx_ratios.append(ar)

all_results["Recursive QAOA"] = [recursive_p_means, recursive_p_ratios, recursive_p_approx_ratios]

# %%
display_boxplots_results(recursive_p_means, recursive_p_ratios, recursive_p_approx_ratios, prefix='Recursive ')

# %% [markdown]
# ### Recursive WarmStart QAOA

# %%
from recursive_ws_helper import *

# %%
ws_recursive_p_means = []
ws_recursive_p_ratios = []
ws_recursive_p_approx_ratios = []

for p in range(1,max_p+1):
    opt_epsilon = ws_opt_epsilons[p-1]
    m, r, ar = start_recursive_ws_qaoa_evaluation(max_cut, eval_num=eval_num, reps=p, epsilon=opt_epsilon)
    ws_recursive_p_means.append(m)
    ws_recursive_p_ratios.append(r)
    ws_recursive_p_approx_ratios.append(ar)
    
all_results["Recursive WarmStrart QAOA"] = [ws_recursive_p_means, ws_recursive_p_ratios, ws_recursive_p_approx_ratios, ws_opt_epsilons]

# %%
display_boxplots_results(ws_recursive_p_means, ws_recursive_p_ratios, ws_recursive_p_approx_ratios, prefix='Recursive WarmStart ')

# %% [markdown]
# ## Results

# %%
from results_helper import *

# %%
means_df, ratio_df, approx_ratios_df = generate_dataframes(all_results)

# %% [markdown]
# ### Metric Mean

# %%
means_df

# %% [markdown]
# ### Metric Ratio

# %%
ratio_df

# %% [markdown]
# ### Metric Approximation Ratio

# %%
approx_ratios_df

# %%
# Save results 
with open(f'comparison_simulator_{graph.name}_results.npy', 'wb') as f:
    np.save(f, all_results)
