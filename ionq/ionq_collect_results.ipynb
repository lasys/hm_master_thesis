# %%
from ionq_collect_results import *
from IPython import display

# %%
print_parameters()
# Out:
# Optimizers: ['SPSA', 'COBYLA'] with MaxIter of 5
# Number of shots: 1000
# Repitions: [ 1; 10 ]
# Gamma value interval: [ -3.141592653589793; 3.141592653589793 ]
# Beta value interval: [ 3.141592653589793;-3.141592653589793 ]
# Number of Optuna Trials: 5

# %% [markdown]
# ## Results from IonQ-Simulator

# %%
results = parse_results_from_html()

# %%
display.HTML(results)
# Out:
#         <div style="width: 100%;font-size:14px">
#                 <div style="width: 50%; float:left;;">
#                 <br><br>
#                 <b>Warmstart Mitiq Error Mitigation</b><br>
#                 <br>
#                 Repetitions: 1 <br>
#                 Mean: -29.633 <br>
#                 Highest Value: 0 with 1.0% <br>
#                 Lowest  Value: -35 with  2.2 % <br>
#                 Highest Probability:-34 with 44.1 % <br>
#                 <br><br>
#                 </div>
#                 <div style="margin-left: 50%;"> <img src="data:image/png;base64,...
# "/> </div>
#         </div>
#         <br>
#
#         <div style="width: 100%;font-size:14px">
#                 <div style="width: 50%; float:left;;">
#                 <br><br>
#                 <b>Error Mitigation</b><br>
#                 <br>
#                 Repetitions: 3 <br>
#                 Mean: -27.933 <br>
#                 Highest Value: 0 with 0.1% <br>
# ...
